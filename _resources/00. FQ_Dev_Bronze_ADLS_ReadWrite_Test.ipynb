# %%
# %sql
SELECT CURRENT_METASTORE();

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# List files in the ADLS container
dbutils.fs.ls("abfss://fq-dev-bronze-container@fqadfstoragedev.dfs.core.windows.net/")

# %%
# Write a test file
dbutils.fs.put("abfss://fq-dev-bronze-container@fqadfstoragedev.dfs.core.windows.net/test.txt", "Hello FoodQuest!", overwrite=True)

# %%
# Read the test file
dbutils.fs.head("abfss://fq-dev-bronze-container@fqadfstoragedev.dfs.core.windows.net/test.txt")

# %%
# Confirm the file exists
dbutils.fs.ls("abfss://fq-dev-bronze-container@fqadfstoragedev.dfs.core.windows.net/")
