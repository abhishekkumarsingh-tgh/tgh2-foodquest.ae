-- %%
show create table fq_dev_catalog.gold.sales_channel_wise

-- %%
select * from fq_dev_catalog.gold.sales_channel_wise

-- %%
REFRESH TABLE fq_dev_catalog.gold.sales_channel_wise;

-- %%
%python
display(spark.table("fq_dev_catalog.gold.sales_channel_wise").schema)

-- %%
SELECT  ordinal_position, table_catalog, table_schema, table_name, column_name, full_data_type, data_type, is_nullable, comment FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'gold' and comment is not null

-- %%
%sql
SELECT * FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'audit'

-- %%
%sql
SHOW TABLES IN fq_dev_catalog.silver;

-- %%
%sql
SHOW TABLES IN fq_dev_catalog.gold

-- %%
%sql
DESCRIBE TABLE fq_dev_catalog.silver.cost

-- %%
%sql
SELECT * FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'silver'

-- %%
%sql
SELECT  ordinal_position, table_catalog, table_schema, table_name, column_name, full_data_type, comment FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'gold' and comment is not null

-- %%
SELECT  ordinal_position, table_catalog, table_schema, table_name, column_name, full_data_type, comment FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'silver' and comment is not null

-- %%
SELECT  ordinal_position, table_catalog, table_schema, table_name, column_name, data_type, comment FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'bronze' and comment is not null

-- %%
SELECT * FROM fq_dev_catalog.information_schema.columns WHERE table_schema = 'silver'
