-- %%
-- Grant USAGE on the schema
GRANT USAGE ON SCHEMA fq_dev_catalog.silver TO `tgh2@foodquest.ae`;

-- %%
SHOW GRANTS ON SCHEMA fq_dev_catalog.silver;

-- %%
%python
users = ['user1@foodquest.ae', 'user2@foodquest.ae', 'user3@foodquest.ae']

for user in users:
    spark.sql(f"""
        GRANT USAGE ON SCHEMA fq_dev_catalog.silver TO {user};
        GRANT SELECT ON ALL TABLES IN SCHEMA fq_dev_catalog.silver TO {user};
        ALTER DEFAULT PRIVILEGES IN SCHEMA fq_dev_catalog.silver
        GRANT SELECT ON TABLES TO {user};
        GRANT USAGE ON ALL SEQUENCES IN SCHEMA fq_dev_catalog.silver TO {user};
    """)

-- %%
%python
users = ['user1@foodquest.ae', 'user2@foodquest.ae', 'user3@foodquest.ae']
table_name = 'fq_dev_catalog.silver.my_table'

for user in users:
    spark.sql(f'GRANT SELECT ON TABLE {table_name} TO "{user}"')

-- %%
SHOW GRANTS ON SCHEMA fq_dev_catalog.silver;

-- %%
SELECT * FROM system.access.audit

-- %%
SELECT * FROM system.access.audit;

-- %%
SELECT * FROM information_schema.table_privileges;
